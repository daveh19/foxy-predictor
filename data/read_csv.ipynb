# %%
import csv

# %%
reader = csv.DictReader(open('allensbach.csv', 'rb'))
dict_list = []
for line in reader:
    dict_list.append(line)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-8-242f1f5f890d> in <module>()
#       1 reader = csv.DictReader(open('allensbach.csv', 'rb'))
#       2 dict_list = []
# ----> 3 for line in reader:
#       4     dict_list.append(line)
#
# C:\Users\jiame\Anaconda3\lib\csv.py in __next__(self)
#     107         if self.line_num == 0:
#     108             # Used only for its side effect.
# --> 109             self.fieldnames
#     110         row = next(self.reader)
#     111         self.line_num = self.reader.line_num
#
# C:\Users\jiame\Anaconda3\lib\csv.py in fieldnames(self)
#      94         if self._fieldnames is None:
#      95             try:
# ---> 96                 self._fieldnames = next(self.reader)
#      97             except StopIteration:
#      98                 pass
#
# ...

# %%
dict_list
# Out:
# [{'<!DOCTYPE html>': '<html class="" lang="en">'},
#  {'<!DOCTYPE html>': '<head prefix="og: http://ogp.me/ns#">'},
#  {'<!DOCTYPE html>': '<meta charset="utf-8">'},
#  {'<!DOCTYPE html>': '<meta content="IE=edge" http-equiv="X-UA-Compatible">'},
#  {'<!DOCTYPE html>': '<meta content="object" property="og:type">'},
#  {'<!DOCTYPE html>': '<meta content="GitLab" property="og:site_name">'},
#  {'<!DOCTYPE html>': '<meta content="data/allensbach.csv Â· master Â· Moritz Daniel Boehle / Foxy Predictor" property="og:title">'},
#  {'<!DOCTYPE html>': '<meta content="tubIT - GitLab Dienst" property="og:description">'},
#  {'<!DOCTYPE html>': '<meta content="https://gitlab.tubit.tu-berlin.de/uploads/project/avatar/13767/Fox-Logo-Design.jpeg" property="og:image">'},
#  {'<!DOCTYPE html>': '<meta content="https://gitlab.tubit.tu-berlin.de/moboehle/Predictor/blob/master/data/allensbach.csv" property="og:url">'},
#  {'<!DOCTYPE html>': '<meta content="summary" property="twitter:card">'},
# ...

# %%
import numpy as np

# %%
with open('emnid.csv') as csvfile:
    reader = csv.reader(csvfile, delimiter=';')
    for row in reader:
        print((row))
# Out:
# ['<!DOCTYPE html>']
# ['<html class="" lang="en">']
# ['<head prefix="og: http://ogp.me/ns#">']
# ['<meta charset="utf-8">']
# ['<meta content="IE=edge" http-equiv="X-UA-Compatible">']
# ['<meta content="object" property="og:type">']
# ['<meta content="GitLab" property="og:site_name">']
# ['<meta content="data/emnid.csv Â· master Â· Moritz Daniel Boehle / Foxy Predictor" property="og:title">']
# ['<meta content="tubIT - GitLab Dienst" property="og:description">']
# ['<meta content="https://gitlab.tubit.tu-berlin.de/uploads/project/avatar/13767/Fox-Logo-Design.jpeg" property="og:image">']
# ['<meta content="https://gitlab.tubit.tu-berlin.de/moboehle/Predictor/blob/master/data/emnid.csv" property="og:url">']
# ['<meta content="summary" property="twitter:card">']
# ['<meta content="data/emnid.csv Â· master Â· Moritz Daniel Boehle / Foxy Predictor" property="twitter:title">']
# ['<meta content="tubIT - GitLab Dienst" property="twitter:description">']
# ...

# %%
import urllib2

url = 'https://gitlab.tubit.tu-berlin.de/moboehle/Predictor/blob/master/data/emnid.csv'
response = urllib2.urlopen(url)
reader = csv.reader(response, delimiter=';')
for row in reader:
    print((row))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-9c1ac4f2a1fa> in <module>()
# ----> 1 import urllib2
#       2
#       3 url = 'https://gitlab.tubit.tu-berlin.de/moboehle/Predictor/blob/master/data/emnid.csv'
#       4 response = urllib2.urlopen(url)
#       5 reader = csv.reader(response, delimiter=';')
#
# ImportError: No module named 'urllib2'

# %%
import pandas as pd

# %%
test = pd.read_csv('emnid.csv', delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-18-db696fa96030> in <module>()
# ----> 1 test = pd.read_csv('emnid.csv', delimiter=';')
#
# ...
