# %%
import csv
import pandas as pd

# %%
# read csv
with open('emnid.csv', encoding='ISO-8859-1') as csvfile:
    reader = csv.reader(csvfile, delimiter=';')
    #for row in reader:
        #print(row)
        
df = pd.read_csv('C:/Users/jiame/Predictor/data/emnid.csv', encoding='ISO-8859-1', delimiter=';')

# %%
df
# Out:
#         Datum  Unnamed: 1  CDU  SPD Grne FDP Linke  AfD Sonstige  Unnamed: 9  \
# 0    29.04.17         NaN  36%  29%    7%  6%    9%   9%       4%         NaN
# 1    22.04.17         NaN  36%  31%    6%  5%    9%   9%       4%         NaN
# 2    15.04.17         NaN  35%  31%    7%  6%    9%   9%       3%         NaN
# 3    08.04.17         NaN  35%  33%    7%  5%    8%   9%       3%         NaN
# 4    01.04.17         NaN  33%  33%    7%  6%    8%   8%       5%         NaN
# 5    25.03.17         NaN  33%  33%    8%  5%    8%   9%       4%         NaN
# 6    18.03.17         NaN  33%  32%    8%  5%    8%   9%       5%         NaN
# 7    11.03.17         NaN  33%  33%    7%  6%    8%   8%       5%         NaN
# 8    04.03.17         NaN  33%  32%    7%  6%    8%  10%       4%         NaN
# 9    25.02.17         NaN  32%  32%    7%  7%    8%   9%       5%         NaN
# 10   18.02.17         NaN  32%  33%    7%  6%    8%   9%       5%         NaN
# ...
